# %% [markdown]
# # SVD - Concatinated Attention Heads - Activation Aware - GPT2Large

# %% [markdown]
# ## Introduction
#
# We will explore the activation aware `c_proj` output for the GPT2 Large model. If this model (and larger sizes) show increasing signs of parameter redundancy then it may be worth exploring a larger model size in my training.

# %%
# %%capture
# ! pip install transformers torch==2.2.2 numpy==1.26.4 safetensors matplotlib pandas

# %% [markdown]
# ## Define the necessary libraries

# %%
# Base libraries
import random

# Maths
import math
import numpy as np
import torch
import pandas as pd
from torch import nn
from tqdm.notebook import tqdm
from pathlib import Path

# Plotting
import matplotlib.pyplot as plt
import seaborn as sns

# Transformers
from transformers import GPT2LMHeadModel, GPT2Tokenizer
from datasets import load_from_disk
from torch.utils.data import DataLoader

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
def set_all_seeds(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    # Ensures deterministic behavior in certain GPU operations
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
set_all_seeds(42)

# %% [markdown]
# ## Load the GPT2Large Model

# %%
# Define the TinyGPT2 model
model = GPT2LMHeadModel.from_pretrained("gpt2-large")
_ = model.to("cpu")
_ = model.eval()
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/666 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B / 3.25GB
# model.safetensors: downloading bytes:           |  0.00B
# Error in sys.excepthook:
# Error in sys.excepthook:
# Traceback (most recent call last):
#   File "/home/dq/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/ipykernel/iostream.py", line 217, in _event_pipe
#     event_pipe = self._local.event_pipe
#                  ^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: '_thread._local' object has no attribute 'event_pipe'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dq/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/IPython/core/interactiveshell.py", line 2166, in excepthook
#     self.showtraceback((etype, value, tb), tb_offset=0)
#     ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dq/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/IPython/core/interactiveshell.py", line 2291, in showtraceback
#     self._showtraceback(etype, value, stb)
#     ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
#   File "/home/dq/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/ipykernel/zmqshell.py", line 669, in _showtraceback
#     sys.stdout.flush()
#     ~~~~~~~~~~~~~~~~^^
#   File "/home/dq/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/ipykernel/iostream.py", line 685, in flush
#     self.pub_thread.schedule(self._flush)
#     ~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^
#   File "/home/dq/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/ipykernel/iostream.py", line 342, in schedule
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "/home/dq/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/ipykernel/iostream.py", line 221, in _event_pipe
#     event_pipe = ctx.socket(zmq.PUSH)
#   File "/home/dq/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/zmq/sugar/context.py", line 352, in socket
#     socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         self, socket_type, **kwargs
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/home/dq/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/zmq/sugar/socket.py", line 164, in __init__
#     super().__init__(
#     ~~~~~~~~~~~~~~~~^
#         ctx_or_socket,
#         ^^^^^^^^^^^^^^
#     ...<2 lines>...
#         copy_threshold=copy_threshold,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "zmq/backend/cython/_zmq.py", line 740, in zmq.backend.cython._zmq.Socket.__init__
#     raise ZMQError()
#
# zmq.error.ZMQError: Too many open files
#
# Original exception was:
# Traceback (most recent call last):
#   File "/home/dq/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/ipykernel/iostream.py", line 217, in _event_pipe
#     event_pipe = self._local.event_pipe
#                  ^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: '_thread._local' object has no attribute 'event_pipe'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dq/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/tqdm/notebook.py", line 262, in update
#     return super().update(n=n)
#            ~~~~~~~~~~~~~~^^^^^
#   File "/home/dq/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/tqdm/std.py", line 1248, in update
#     self.refresh(lock_args=self.lock_args)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dq/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/tqdm/std.py", line 1355, in refresh
#     self.display()
#     ~~~~~~~~~~~~^^
#   File "/home/dq/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/tqdm/notebook.py", line 159, in display
#     pbar.value = self.n
#     ^^^^^^^^^^
#   File "/home/dq/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/traitlets/traitlets.py", line 734, in __set__
#     self.set(obj, value)
#     ~~~~~~~~^^^^^^^^^^^^
#   File "/home/dq/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/traitlets/traitlets.py", line 724, in set
#     obj._notify_trait(self.name, old_value, new_value)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dq/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/traitlets/traitlets.py", line 1520, in _notify_trait
#     self.notify_change(
#     ~~~~~~~~~~~~~~~~~~^
#         Bunch(
#         ^^^^^^
#     ...<5 lines>...
#         )
#         ^
#     )
#     ^
#   File "/home/dq/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/ipywidgets/widgets/widget.py", line 700, in notify_change
#     self.send_state(key=name)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^
#   File "/home/dq/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/ipywidgets/widgets/widget.py", line 586, in send_state
#     self._send(msg, buffers=buffers)
#     ~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dq/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/ipywidgets/widgets/widget.py", line 825, in _send
#     self.comm.send(data=msg, buffers=buffers)
#     ~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dq/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/comm/base_comm.py", line 144, in send
#     self.publish_msg(
#     ~~~~~~~~~~~~~~~~^
#         "comm_msg",
#         ^^^^^^^^^^^
#     ...<2 lines>...
#         buffers=buffers,
#         ^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/home/dq/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/ipykernel/comm/comm.py", line 37, in publish_msg
#     self.kernel.session.send(
#     ~~~~~~~~~~~~~~~~~~~~~~~~^
#         self.kernel.iopub_socket,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^
#     ...<5 lines>...
#         buffers=buffers,
#         ^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/home/dq/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/jupyter_client/session.py", line 867, in send
#     stream.send_multipart(to_send, copy=copy)
#     ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
#   File "/home/dq/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/ipykernel/iostream.py", line 433, in send_multipart
#     return self.io_thread.send_multipart(*args, **kwargs)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/dq/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/ipykernel/iostream.py", line 351, in send_multipart
#     self.schedule(lambda: self._really_send(*args, **kwargs))
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dq/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/ipykernel/iostream.py", line 342, in schedule
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "/home/dq/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/ipykernel/iostream.py", line 221, in _event_pipe
#     event_pipe = ctx.socket(zmq.PUSH)
#   File "/home/dq/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/zmq/sugar/context.py", line 352, in socket
#     socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         self, socket_type, **kwargs
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/home/dq/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/zmq/sugar/socket.py", line 164, in __init__
#     super().__init__(
#     ~~~~~~~~~~~~~~~~^
#         ctx_or_socket,
#         ^^^^^^^^^^^^^^
#     ...<2 lines>...
#         copy_threshold=copy_threshold,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "zmq/backend/cython/_zmq.py", line 740, in zmq.backend.cython._zmq.Socket.__init__
#     raise ZMQError()
#
# zmq.error.ZMQError: Too many open files
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dq/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/ipykernel/iostream.py", line 217, in _event_pipe
#     event_pipe = self._local.event_pipe
#                  ^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: '_thread._local' object has no attribute 'event_pipe'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dq/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/huggingface_hub/utils/_xet_progress_reporting.py", line 153, in update_progress
#     _update_transfer_bar(self.transfer_bar, transfer_inc)
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dq/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/huggingface_hub/utils/_xet_progress_reporting.py", line 35, in _update_transfer_bar
#     bar.update(inc)
#     ~~~~~~~~~~^^^^^
#   File "/home/dq/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/tqdm/notebook.py", line 267, in update
#     self.disp(bar_style='danger')
#     ~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
#   File "/home/dq/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/tqdm/notebook.py", line 173, in display
#     rtext.value = right
#     ^^^^^^^^^^^
#   File "/home/dq/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/traitlets/traitlets.py", line 734, in __set__
#     self.set(obj, value)
#     ~~~~~~~~^^^^^^^^^^^^
#   File "/home/dq/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/traitlets/traitlets.py", line 724, in set
#     obj._notify_trait(self.name, old_value, new_value)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dq/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/traitlets/traitlets.py", line 1520, in _notify_trait
#     self.notify_change(
#     ~~~~~~~~~~~~~~~~~~^
#         Bunch(
#         ^^^^^^
#     ...<5 lines>...
#         )
#         ^
#     )
#     ^
#   File "/home/dq/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/ipywidgets/widgets/widget.py", line 700, in notify_change
#     self.send_state(key=name)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^
#   File "/home/dq/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/ipywidgets/widgets/widget.py", line 586, in send_state
#     self._send(msg, buffers=buffers)
#     ~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dq/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/ipywidgets/widgets/widget.py", line 825, in _send
#     self.comm.send(data=msg, buffers=buffers)
#     ~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dq/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/comm/base_comm.py", line 144, in send
#     self.publish_msg(
#     ~~~~~~~~~~~~~~~~^
#         "comm_msg",
#         ^^^^^^^^^^^
#     ...<2 lines>...
#         buffers=buffers,
#         ^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/home/dq/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/ipykernel/comm/comm.py", line 37, in publish_msg
#     self.kernel.session.send(
#     ~~~~~~~~~~~~~~~~~~~~~~~~^
#         self.kernel.iopub_socket,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^
#     ...<5 lines>...
#         buffers=buffers,
#         ^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/home/dq/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/jupyter_client/session.py", line 867, in send
#     stream.send_multipart(to_send, copy=copy)
#     ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
#   File "/home/dq/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/ipykernel/iostream.py", line 433, in send_multipart
#     return self.io_thread.send_multipart(*args, **kwargs)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/dq/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/ipykernel/iostream.py", line 351, in send_multipart
#     self.schedule(lambda: self._really_send(*args, **kwargs))
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dq/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/ipykernel/iostream.py", line 342, in schedule
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "/home/dq/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/ipykernel/iostream.py", line 221, in _event_pipe
#     event_pipe = ctx.socket(zmq.PUSH)
#   File "/home/dq/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/zmq/sugar/context.py", line 352, in socket
#     socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         self, socket_type, **kwargs
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/home/dq/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/zmq/sugar/socket.py", line 164, in __init__
#     super().__init__(
#     ~~~~~~~~~~~~~~~~^
#         ctx_or_socket,
#         ^^^^^^^^^^^^^^
#     ...<2 lines>...
#         copy_threshold=copy_threshold,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "zmq/backend/cython/_zmq.py", line 740, in zmq.backend.cython._zmq.Socket.__init__
#     raise ZMQError()
#
# zmq.error.ZMQError: Too many open files
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/huggingface_hub/file_download.py:563, in xet_get(incomplete_path, xet_file_data, headers, expected_size, displayed_filename, tqdm_class, _tqdm_bar)
#     562 try:
# --> 563     with session.new_file_download_group(
#     564         token_refresh_url=xet_file_data.refresh_route,
#     565         token_refresh_headers=headers,
#     566         custom_headers=xet_headers,
#     567         progress_callback=progress.update_progress,
#     568     ) as group:
#     569         group.start_download_file(
#     570             XetFileInfo(xet_file_data.file_hash, expected_size), str(incomplete_path.absolute())
#     571         )
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Define the TinyGPT2 model
# ----> 2 model = GPT2LMHeadModel.from_pretrained("gpt2-large")
#       3 _ = model.to("cpu")
#       4 _ = model.eval()
#
# File ~/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/transformers/modeling_utils.py:4355, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, fusion_config, disable_mmap, *model_args, **kwargs)
#    4350     logger.warning_once(
#    4351         "A kernel_config was provided but use_kernels is False; setting use_kernels=True automatically. To suppress this warning, explicitly set use_kernels to True."
#    4352     )
#    4353     use_kernels = True
# -> 4355 checkpoint_files, sharded_metadata = _get_resolved_checkpoint_files(
#    4356     pretrained_model_name_or_path=pretrained_model_name_or_path,
#    4357     variant=variant,
#    4358     gguf_file=gguf_file,
#    4359     use_safetensors=use_safetensors,
#    4360     download_kwargs=download_kwargs_with_commit,
#    4361     user_agent=user_agent,
#    4362     is_remote_code=cls.is_remote_code(),
#    4363     transformers_explicit_filename=getattr(config, "transformers_weights", None),
#    4364     tqdm_class=tqdm_class,
#    4365 )
#    4367 is_quantized = hf_quantizer is not None
#    4369 # Find the correct dtype based on current state
#
# File ~/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/transformers/modeling_utils.py:695, in _get_resolved_checkpoint_files(pretrained_model_name_or_path, variant, gguf_file, use_safetensors, user_agent, is_remote_code, transformers_explicit_filename, download_kwargs, tqdm_class)
#     683 can_auto_convert = (
#     684     not is_offline_mode()  # for obvious reasons
#     685     # If we are in a CI environment or in a pytest run, we prevent the conversion
#    (...)    688     and subfolder == ""  # converter bot does not work on subfolders
#     689 )
#     691 try:
#     692     # Load from URL or cache if already cached
#     693     # Since we set _raise_exceptions_for_missing_entries=False, we don't get an exception but a None
#     694     # result when internet is up, the repo and revision exist, but the file does not.
# --> 695     resolved_archive_file = cached_file(pretrained_model_name_or_path, filename, **cached_file_kwargs)
#     697     # Try safetensors files first if not already found
#     698     if resolved_archive_file is None and filename == _add_variant(SAFE_WEIGHTS_NAME, variant):
#     699         # Maybe the checkpoint is sharded, we try to grab the index name in this case.
#
# File ~/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/transformers/utils/hub.py:293, in cached_file(path_or_repo_id, filename, **kwargs)
#     238 def cached_file(
#     239     path_or_repo_id: str | os.PathLike,
#     240     filename: str,
#     241     **kwargs,
#     242 ) -> str | None:
#     243     """
#     244     Tries to locate a file in a local folder and repo, downloads and cache it if necessary.
#     245
#    (...)    291     ```
#     292     """
# --> 293     file = cached_files(path_or_repo_id=path_or_repo_id, filenames=[filename], **kwargs)
#     294     file = file[0] if file is not None else file
#     295     return file
#
# File ~/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/transformers/utils/hub.py:437, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, tqdm_class, **deprecated_kwargs)
#     434 try:
#     435     if len(full_filenames) == 1:
#     436         # This is slightly better for only 1 file
# --> 437         hf_hub_download(
#     438             path_or_repo_id,
#     439             filenames[0],
#     440             subfolder=None if len(subfolder) == 0 else subfolder,
#     441             repo_type=repo_type,
#     442             revision=revision,
#     443             cache_dir=cache_dir,
#     444             user_agent=user_agent,
#     445             force_download=force_download,
#     446             proxies=proxies,
#     447             token=token,
#     448             local_files_only=local_files_only,
#     449             tqdm_class=tqdm_class,
#     450         )
#     451     else:
#     452         snapshot_download(
#     453             path_or_repo_id,
#     454             allow_patterns=full_filenames,
#    (...)    463             tqdm_class=tqdm_class,
#     464         )
#
# File ~/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/huggingface_hub/utils/_validators.py:88, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      84         validate_repo_id(arg_value)
#      86 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
# ---> 88 return fn(*args, **kwargs)
#
# File ~/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/huggingface_hub/file_download.py:1013, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, etag_timeout, token, local_files_only, headers, endpoint, tqdm_class, dry_run)
#     992     return _hf_hub_download_to_local_dir(
#     993         # Destination
#     994         local_dir=local_dir,
#    (...)   1010         dry_run=dry_run,
#    1011     )
#    1012 else:
# -> 1013     return _hf_hub_download_to_cache_dir(
#    1014         # Destination
#    1015         cache_dir=cache_dir,
#    1016         # File info
#    1017         repo_id=repo_id,
#    1018         filename=filename,
#    1019         repo_type=repo_type,
#    1020         revision=revision,
#    1021         # HTTP info
#    1022         endpoint=endpoint,
#    1023         etag_timeout=etag_timeout,
#    1024         headers=hf_headers,
#    1025         token=token,
#    1026         # Additional options
#    1027         local_files_only=local_files_only,
#    1028         force_download=force_download,
#    1029         tqdm_class=tqdm_class,
#    1030         dry_run=dry_run,
#    1031     )
#
# File ~/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/huggingface_hub/file_download.py:1241, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, token, local_files_only, force_download, tqdm_class, dry_run)
#    1238 # Local file doesn't exist or etag isn't a match => retrieve file from remote (or cache)
#    1240 with WeakFileLock(lock_path):
# -> 1241     _download_to_tmp_and_move(
#    1242         incomplete_path=Path(blob_path + ".incomplete"),
#    1243         destination_path=Path(blob_path),
#    1244         url_to_download=url_to_download,
#    1245         headers=headers,
#    1246         expected_size=expected_size,
#    1247         filename=filename,
#    1248         force_download=force_download,
#    1249         etag=etag,
#    1250         xet_file_data=xet_file_data,
#    1251         tqdm_class=tqdm_class,
#    1252     )
#    1253     if not os.path.exists(pointer_path):
#    1254         _create_symlink(blob_path, pointer_path, new_blob=True)
#
# File ~/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/huggingface_hub/file_download.py:1925, in _download_to_tmp_and_move(incomplete_path, destination_path, url_to_download, headers, expected_size, filename, force_download, etag, xet_file_data, tqdm_class)
#    1923 if xet_file_data is not None and is_xet_available():
#    1924     logger.debug("Xet Storage is enabled for this repo. Downloading file from Xet Storage..")
# -> 1925     xet_get(
#    1926         incomplete_path=tmp_path,
#    1927         xet_file_data=xet_file_data,
#    1928         headers=headers,
#    1929         expected_size=expected_size,
#    1930         displayed_filename=filename,
#    1931         tqdm_class=tqdm_class,
#    1932     )
#    1933 else:
#    1934     if xet_file_data is not None and not constants.HF_HUB_DISABLE_XET:
#
# File ~/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/huggingface_hub/file_download.py:553, in xet_get(incomplete_path, xet_file_data, headers, expected_size, displayed_filename, tqdm_class, _tqdm_bar)
#     549 xet_headers = xet_headers_without_auth(headers)
#     551 session = get_xet_session()
# --> 553 with XetDownloadProgressReporter(
#     554     reconstruction_desc=f"{displayed_filename}: reconstructing file",
#     555     transfer_desc=f"{displayed_filename}: downloading bytes",
#     556     total=expected_size,
#     557     log_level=logger.getEffectiveLevel(),
#     558     name="huggingface_hub.xet_get",
#     559     tqdm_class=tqdm_class,
#     560     external_reconstruction_bar=_tqdm_bar,
#     561 ) as progress:
#     562     try:
#     563         with session.new_file_download_group(
#     564             token_refresh_url=xet_file_data.refresh_route,
#     565             token_refresh_headers=headers,
#     566             custom_headers=xet_headers,
#     567             progress_callback=progress.update_progress,
#     568         ) as group:
#
# File ~/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/huggingface_hub/utils/_xet_progress_reporting.py:179, in XetDownloadProgressReporter.__exit__(self, *args)
#     178 def __exit__(self, *args) -> None:
# --> 179     self.close()
#
# File ~/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/huggingface_hub/utils/_xet_progress_reporting.py:169, in XetDownloadProgressReporter.close(self)
#     162 """Close bars owned by this reporter.
#     163
#     164 Standalone downloads finish the transfer bar first (snap hidden total to ``n``), then close it.
#     165 Aggregated and external bars (e.g. snapshot ``_AggregatedTqdm`` or a reused ``_tqdm_bar``) are left
#     166 open — their parent caller owns their lifecycle.
#     167 """
#     168 if self.transfer_bar is not None and self._owns_transfer_bar:
# --> 169     _finish_transfer_bar(self.transfer_bar)
#     170     if hasattr(self.transfer_bar, "close"):
#     171         self.transfer_bar.close()
#
# File ~/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/huggingface_hub/utils/_xet_progress_reporting.py:47, in _finish_transfer_bar(bar)
#      45 if n > 0 and hasattr(bar, "total") and bar.total != n:
#      46     bar.total = n
# ---> 47     bar.refresh()
#
# File ~/.pyenv/versions/3.13.14/envs/mla/lib/python3.13/site-packages/tqdm/std.py:1354, in tqdm.refresh(self, nolock, lock_args)
#    1352             return False
#    1353     else:
# -> 1354         self._lock.acquire()
#    1355 self.display()
#    1356 if not nolock:
#
# KeyboardInterrupt:

# %%
# Load the model and tokenizer
tokenizer = GPT2Tokenizer.from_pretrained("gpt2-large")

# %% [markdown]
# ## Load the OpenWebText validation dataset

# %%
# Define the model path
parent = Path.cwd().parent
data_path = parent / "training_data/TinyGPT2/pretraining/Skylion007__openwebtext_ac1e385807"

# %%
# Load the dataset from local
dataset = load_from_disk(str(data_path))

# %%
# Define a dataloader
dataset.set_format(type="torch", columns=["input_ids", "attention_mask"])
loader = DataLoader(dataset["validation"], batch_size=512)

# %%
# Define the first batch
first_batch = next(iter(loader))
input_ids = first_batch["input_ids"]
attention_mask = first_batch["attention_mask"]

# %% [markdown]
# ## Pass the inputs through the model

# %% [markdown]
# ## Extract the concat attention heads

# %% [markdown]
# We wish to explore the activations that would be combined with the $W_o$ weights matrix, these themselves are a set of output attention heads that have been concatenated together. To do so we add a hook to each attention layer of the GPT2 model where the attention head activations are concatenated together. This captures the batches concatenated activation values, which we need to reshape to (-1, hidden_size=1024) to ensure that we can compare each of these 1024 dimensions for redundancy. We will then perform a SVD analysis on these matrices after a batch of wiki data has been passed through the model.

# %%
# Define the activations dictionary
activations = {}

# Define the hook fn
def get_activation(name):
    def hook(model, input, output):
        # We want the input to the dense layer (the concatenated head outputs)
        activations[name] = output.detach().cpu()
    return hook

# %%
# Register hooks for all layers' output projections
for i in range(model.config.num_hidden_layers):
    _ = model.transformer.h[i].attn.c_proj.register_forward_hook(get_activation(f'layer_{i}'))

# %%
# Pass data through the model
with torch.no_grad():
    first_batch = {k: v.to("cpu") for k, v in first_batch.items()}
    output = model(**first_batch)

# %% [markdown]
# ## Examine the activations

# %%
# Examine the number of activations captured
len(activations)
activations["layer_0"].shape

# %%
# Define the hidden size
hidden_size = activations["layer_0"].shape[-1]

# %%
# Extract the concated head data
activations_list = list(activations.values())

# %%
# Reshape the activation data
activations_list = [item.reshape(-1, hidden_size) for item in activations_list]
activations_list[0].shape

# %%
# Save the filtered activations
flattened_activations_list = []

# Filter padding from hooks
for activations in tqdm(activations_list, total=len(activations_list)):
    act_np = np.array(activations)
    mask_np = np.array(attention_mask).flatten()
    
    # Use NumPy's boolean indexing to keep only non-padding tokens (where mask == 1)
    filtered_act = act_np[mask_np > 0]
    
    # Convert back to MLX for the SVD
    flattened_activations_list.append(filtered_act)

# %%
# Examine the shape of the filtered data
flattened_activations_list[0].shape

# %% [markdown]
# ## Apply SVD to each layer

# %% [markdown]
# ## Calculate the effective rank of each activation matrix

# %% [markdown]
# ### Retension based rank (Energy Cutoff)

# %% [markdown]
# This is a threshold based matric, which focuses on the question, how many singular values do I need to preserve at least $x\%$ of the matrices total energy. This allows for the direct calculation of compressibility of a matrix.
#
# In particular, in ML the singular value represents the stretch of each dimension, but S squared represents the energy (or variance) contained in that dimension.

# %%
def calculate_retension_based_rank(S, threshold_list):
    """
    This function take a matrices singular values and estimate the retension based rank for a list of thresholds.
    It essentially takes the singular values, squares them to represent each Wo dimensions variance and subsequently, calculates 
    the cumulative percentage energy values. Then taking the thresholds we find the number of dimensions that combine to cross the 
    pre-defined minimum thresholds.
    """

    # Calculate the cumulative percentage energy values -> Cumulative sum / total energy (S**2)
    cumulative_energy = np.cumsum(S**2) / np.sum(S**2)

    # Find smallest k such that cumulative energy >= alpha
    retention_based_rank_values = [{threshold: np.searchsorted(cumulative_energy, threshold) + 1} for threshold in threshold_list]

    return retention_based_rank_values

# %% [markdown]
# ### Entropy based effective rank

# %% [markdown]
# Given singular values $S$ of a matrix $W$, we want to calculate the effective rank, such that:
#
# - If the spectrum is uniform → rank is high
# - If a few singular values dominate → rank is low
# - If one singular value dominates → rank ≈ 1
# - If all singular values are equal → rank = full rank
#
# The entropy-based effective rank satisfies all of these.

# %%
def calculate_effective_rank(S):
    """
    Calculating the entropy based effective rank value. Remember that S**2 represents the energy of that dimension and thus we initially 
    calculate a energy based probability distribution which sums to 1. We then measure the uncertainty via the entropy calculation. We then
    convert back to a rank value by taking the exp.
    """

    # Calculate the energy based probability
    p = (S**2) / np.sum(S**2)

    # Calculate the Shannon entropy (log scale)
    H = -np.sum(p * np.log(p))
    
    # Calculate the effective rank (R scale)
    entropy_based_effective_rank = np.exp(H)

    return entropy_based_effective_rank

# %%
def calculate_SVD_rank_metrics(H):
    """
    First calculate the SVD and then calculate the retension based rank value and entropy baesd effective rank values. 
    """

    # Create a list to store the results
    svd_layers = []
    
    # For each layers WO matrix
    for layer, h in tqdm(enumerate(H), total=len(H)):

        # Center each of the 312 dimensions across all tokens (variance about the mean,
        # not energy about the origin — removes the anisotropy/mean-offset direction)
        h = h - h.mean(axis=0, keepdims=True)
    
        # Calculate the SVD
        U, S, VT = np.linalg.svd(h, full_matrices=False)
    
        # Calculate the retension based rank values
        retension_based_rank_values = calculate_retension_based_rank(S, [0.99, 0.999])    
    
        # Calculate the entropy based effective rank
        entropy_based_effective_rank = calculate_effective_rank(S)
        
        # Store the results
        svd_layers.append({
            "layer": layer,
            "U": U,
            "S": S,
            "VT": VT,
            "retension_based_rank_values": retension_based_rank_values,
            "entropy_based_effective_rank": entropy_based_effective_rank,
        })

    return svd_layers

# %%
# Calculate the entropy based effective rank and also retention based rank values
svd_layers = calculate_SVD_rank_metrics(flattened_activations_list)

# %%
# Convert to a dataframe
svd_layers_df = pd.DataFrame(svd_layers)

# %%
# Expand out the retensio based rank values
svd_layers_df_expanded = pd.concat([
    svd_layers_df.drop(columns='retension_based_rank_values'),
    svd_layers_df['retension_based_rank_values'].apply(lambda lst: {k: v for d in lst for k, v in d.items()}).apply(pd.Series)
], axis=1)

# %%
# Rename the columns
svd_layers_df_expanded = svd_layers_df_expanded.rename(columns={0.99: 'r99', 0.999: 'r99.9'})

# %% [markdown]
# ## Plot the curves of the retension based rank values

# %%
# Plot the  
ax = svd_layers_df_expanded.plot(x='layer', y=['r99', 'r99.9', 'entropy_based_effective_rank'], figsize=(12, 6))

# Add a custom horizontal line
_ = plt.axhline(y=hidden_size, color='red', linestyle='--', label='Threshold Line')

# Add titles, labels and legend
_ = plt.ylabel('Retention/Effective Rank')
_ = plt.xlabel('Layer')
_ = plt.title('Retention/Effective Ranks by Layer')
_ = ax.legend(['Retention 99%', 'Retention 99.9%', "Effective Rank", f"Full Rank ({hidden_size})"])
plt.show()

# %% [markdown]
# ## Calculate the average value across the different layers

# %%
# Calculate the average retension/effective rank across the layers
print("r99: ", f"{svd_layers_df_expanded['r99'].mean():.2f}")
print("r99.9: ", f"{svd_layers_df_expanded['r99.9'].mean():.2f}")
print("entropy_based_effective_rank: ", f"{svd_layers_df_expanded['entropy_based_effective_rank'].mean():.2f}")

# %% [markdown]
# ## Conclusion

# %% [markdown]
# The effective rank varies across the layers. Starting low and then increasing over time. I would still suggest from this plot that there is redundancy in the model.
